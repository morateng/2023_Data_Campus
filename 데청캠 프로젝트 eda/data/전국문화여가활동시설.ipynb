# %%
import pandas as pd

# %%
df = pd.read_csv('../data/전국문화여가활동시설(액티비티).csv')
df.head()
# Out:
#    FCLTY_NM CTGRY_ONE_NM CTGRY_TWO_NM CTGRY_THREE_NM CTPRVN_NM SIGNGU_NM  \
# 0   행복스크린골프     레저/체육/공원       지역레저시설          스크린골프       강원도       강릉시
# 1   행복스크린골프     레저/체육/공원       지역레저시설          스크린골프       강원도       강릉시
# 2  시니어해핑탁구장     레저/체육/공원       지역체육시설            탁구장       강원도       강릉시
# 3  시니어해핑탁구장     레저/체육/공원       지역체육시설            탁구장       강원도       강릉시
# 4  넘버원스크린골프     레저/체육/공원       지역레저시설          스크린골프       강원도       강릉시
#
#   LEGALDONG_NM LI_NM     LNBR_NO   ROAD_NM  ... ZIP_NO           RDNMADR_NM  \
# 0          포남동   NaN  1090-17 번지       가작로  ...  25477      강원도 강릉시 가작로 275
# 1          포남동   NaN  1090-17 번지       가작로  ...  25477      강원도 강릉시 가작로 275
# 2          포남동   NaN  1090-10 번지       가작로  ...  25477      강원도 강릉시 가작로 277
# 3          포남동   NaN  1090-10 번지       가작로  ...  25477      강원도 강릉시 가작로 277
# 4          포남동   NaN    551-2 번지  가작로287번길  ...  25477  강원도 강릉시 가작로287번길 33
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24537 entries, 0 to 24536
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FCLTY_NM         24537 non-null  object
#  1   CTGRY_ONE_NM     24537 non-null  object
#  2   CTGRY_TWO_NM     24537 non-null  object
#  3   CTGRY_THREE_NM   24537 non-null  object
#  4   CTPRVN_NM        24537 non-null  object
#  5   SIGNGU_NM        24463 non-null  object
#  6   LEGALDONG_NM     24537 non-null  object
#  7   LI_NM            6416 non-null   object
#  8   LNBR_NO          24537 non-null  object
#  9   ROAD_NM          24537 non-null  object
#  10  BULD_NO          24537 non-null  object
#  11  LC_LA            24537 non-null  float64
#  12  LC_LO            24537 non-null  float64
#  13  ZIP_NO           24537 non-null  int64
#  14  RDNMADR_NM       24537 non-null  object
#  15  LNM_ADDR         24537 non-null  object
# ...

# %%
df['CTGRY_THREE_NM'].unique()
# Out:
# array(['스크린골프', '탁구장', '패러글라이딩', '레일바이크', '테니스장', '낚시터', '방탈출', '볼링장',
#        '농구장', '짚라인', '야구연습장', '실외골프연습장', '실내골프연습장', '스케이트장', '골프장',
#        '클라이밍', '풋살장', '유람선', 'VR', '눈썰매', '래프팅', '배드민턴장', '수상스키', '사격장',
#        '스키장', '서바이벌'], dtype=object)

# %%
df['CTPRVN_NM'].unique()
# Out:
# array(['강원도', '경기도', '경상남도', '경상북도', '광주광역시', '대구광역시', '대전광역시', '부산광역시',
#        '서울특별시', '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도', '제주특별자치도',
#        '충청남도', '충청북도'], dtype=object)

# %%
df_seoul = df[df['CTPRVN_NM'].str.contains('서울특별시')]
df_seoul
# Out:
#             FCLTY_NM CTGRY_ONE_NM CTGRY_TWO_NM CTGRY_THREE_NM CTPRVN_NM  \
# 16993  코드이스케이프 가로수길점     레저/체육/공원         액티비티            방탈출     서울특별시
# 16994  코드이스케이프 가로수길점     레저/체육/공원         액티비티            방탈출     서울특별시
# 16995     라인볼링센터 강남점     레저/체육/공원       지역체육시설            볼링장     서울특별시
# 16996     라인볼링센터 강남점     레저/체육/공원       지역체육시설            볼링장     서울특별시
# 16997    세븐클루스 강남2호점     레저/체육/공원         액티비티            방탈출     서울특별시
# ...              ...          ...          ...            ...       ...
# 20428        마스터클라이밍     레저/체육/공원       지역체육시설           클라이밍     서울특별시
# 20429      현대야외스크린골프     레저/체육/공원       지역레저시설          스크린골프     서울특별시
# 20430          핵파워탁구     레저/체육/공원       지역체육시설            탁구장     서울특별시
# 20431      서일대학교 농구장     레저/체육/공원       지역체육시설            농구장     서울특별시
# 20432         삼보골프스쿨     레저/체육/공원       지역레저시설          스크린골프     서울특별시
#
#       SIGNGU_NM LEGALDONG_NM LI_NM    LNBR_NO    ROAD_NM  ... ZIP_NO  \
# ...
