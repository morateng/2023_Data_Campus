# %%
import pandas as pd

# %%
df = pd.read_csv('../data/체육 생활 이용정보_202303.csv')

# %%
df_seoul = df[df['CTPRVN_NM'].str.contains('서울특별시')]

# %%
df_seoul=df_seoul[df_seoul['BASE_YM']==202303]
df_seoul
# Out:
#        BASE_YM   CTPRVN_CD CTPRVN_NM   SIGNGU_CD SIGNGU_NM  \
# 69080   202303  1100000000     서울특별시  1111000000       종로구
# 69081   202303  1100000000     서울특별시  1111000000       종로구
# 69082   202303  1100000000     서울특별시  1111000000       종로구
# 69083   202303  1100000000     서울특별시  1111000000       종로구
# 69084   202303  1100000000     서울특별시  1111000000       종로구
# ...        ...         ...       ...         ...       ...
# 69325   202303  1100000000     서울특별시  1174000000       강동구
# 69326   202303  1100000000     서울특별시  1174000000       강동구
# 69327   202303  1100000000     서울특별시  1174000000       강동구
# 69328   202303  1100000000     서울특별시  1174000000       강동구
# 69329   202303  1100000000     서울특별시  1174000000       강동구
#
#        SIGNGU_ACCTO_POPLTN_CO MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM  \
# 69080                  141060          자주이용하는 공공시설 1순위               간이운동장
# 69081                  141060          자주이용하는 민간시설 1순위               체력단련장
# ...

# %%
df_공공간이운동장=df_seoul.loc[69080::10,:]
df_공공간이운동장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
                 'PSNBY_FCLTY_CO', 'PSNBY_FCL_CO_RANK_CO'], axis=1, inplace=True)
df_공공간이운동장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'공공간이운동장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
df_공공간이운동장 = df_공공간이운동장.reindex(['자치구', '공공간이운동장 수'], axis=1)
df_공공간이운동장.set_index('자치구', inplace=True)
df_공공간이운동장
# Out:
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\215306022.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_공공간이운동장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\215306022.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_공공간이운동장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'공공간이운동장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
#       공공간이운동장 수
# 자치구
# 종로구          28
# 중구            3
# 용산구           8
# 성동구           0
# 광진구           5
# 동대문구          5
# ...

# %%
df_공공수영장=df_seoul.loc[69081::10,:]
df_공공수영장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
                 'PSNBY_FCLTY_CO', 'PSNBY_FCL_CO_RANK_CO'], axis=1, inplace=True)
df_공공수영장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'민간체력단련장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
df_공공수영장 = df_공공수영장.reindex(['자치구', '민간체력단련장 수'], axis=1)
df_공공수영장.set_index('자치구', inplace=True)
df_공공수영장
# Out:
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\1078198058.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_민간체력단련장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\1078198058.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_민간체력단련장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'민간체력단련장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
#       민간체력단련장 수
# 자치구
# 종로구          59
# 중구          110
# 용산구          76
# 성동구          78
# 광진구         121
# 동대문구         82
# ...

# %%
df_공공체력단련장=df_seoul.loc[69082::10,:]
df_공공체력단련장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
                 'PSNBY_FCLTY_CO', 'PSNBY_FCL_CO_RANK_CO'], axis=1, inplace=True)
df_공공체력단련장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'공공체력단련장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
df_공공체력단련장 = df_공공체력단련장.reindex(['자치구', '공공체력단련장 수'], axis=1)
df_공공체력단련장.set_index('자치구', inplace=True)
df_공공체력단련장
# Out:
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\1035820450.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_공공체력단련장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\1035820450.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_공공체력단련장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'공공체력단련장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
#       공공체력단련장 수
# 자치구
# 종로구           3
# 중구            5
# 용산구           4
# 성동구           4
# 광진구           1
# 동대문구          7
# ...

# %%
df_골프장_골프연습장=df_seoul.loc[69083::10,:]
df_골프장_골프연습장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
                 'PSNBY_FCLTY_CO', 'PSNBY_FCL_CO_RANK_CO'], axis=1, inplace=True)
df_골프장_골프연습장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'골프/골프연습장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
df_골프장_골프연습장 = df_골프장_골프연습장.reindex(['자치구', '골프/골프연습장 수'], axis=1)
df_골프장_골프연습장.set_index('자치구', inplace=True)
df_골프장_골프연습장
# Out:
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\939288351.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_골프장_골프연습장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\939288351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_골프장_골프연습장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'골프/골프연습장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
#       골프/골프연습장 수
# 자치구
# 종로구           33
# 중구            93
# 용산구           41
# 성동구           54
# 광진구           56
# 동대문구          45
# ...

# %%
df_공공수영장=df_seoul.loc[69084::10,:]
df_공공수영장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
                 'PSNBY_FCLTY_CO', 'PSNBY_FCL_CO_RANK_CO'], axis=1, inplace=True)
df_공공수영장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'공공수영장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
df_공공수영장 = df_공공수영장.reindex(['자치구', '공공수영장 수'], axis=1)
df_공공수영장.set_index('자치구', inplace=True)
df_공공수영장
# Out:
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\305170254.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_공공수영장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\305170254.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_공공수영장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'공공수영장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
#       공공수영장 수
# 자치구
# 종로구         3
# 중구          2
# 용산구         4
# 성동구         4
# 광진구         3
# 동대문구        3
# 중랑구         2
# 성북구         3
# ...

# %%
df_민간수영장=df_seoul.loc[69085::10,:]
df_민간수영장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
                 'PSNBY_FCLTY_CO', 'PSNBY_FCL_CO_RANK_CO'], axis=1, inplace=True)
df_민간수영장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'민간수영장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
df_민간수영장 = df_민간수영장.reindex(['자치구', '민간수영장 수'], axis=1)
df_민간수영장.set_index('자치구', inplace=True)
df_민간수영장
# Out:
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\693896549.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_민간수영장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\693896549.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_민간수영장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'민간수영장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
#       민간수영장 수
# 자치구
# 종로구         0
# 중구          7
# 용산구         3
# 성동구         2
# 광진구         6
# 동대문구        4
# 중랑구         2
# 성북구         6
# ...

# %%
df_당구장=df_seoul.loc[69087::10,:]
df_당구장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
                 'PSNBY_FCLTY_CO', 'PSNBY_FCL_CO_RANK_CO'], axis=1, inplace=True)
df_당구장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'당구장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
df_당구장 = df_당구장.reindex(['자치구', '당구장 수'], axis=1)
df_당구장.set_index('자치구', inplace=True)
df_당구장
# Out:
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\2239659535.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_당구장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\2239659535.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_당구장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'당구장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
#       당구장 수
# 자치구
# 종로구      88
# 중구      170
# 용산구      42
# 성동구      71
# 광진구     129
# 동대문구     83
# 중랑구     106
# 성북구     133
# 강북구      94
# ...

# %%
df_체육도장=df_seoul.loc[69089::10,:]
df_체육도장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
                 'PSNBY_FCLTY_CO', 'PSNBY_FCL_CO_RANK_CO'], axis=1, inplace=True)
df_체육도장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'체육도장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
df_체육도장 = df_체육도장.reindex(['자치구', '체육도장 수'], axis=1)
df_체육도장.set_index('자치구', inplace=True)
df_체육도장
# Out:
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\972982123.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_체육도장.drop(['BASE_YM', 'CTPRVN_CD', 'CTPRVN_NM', 'SIGNGU_CD','SIGNGU_ACCTO_POPLTN_CO', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM',
# C:\Users\morat\AppData\Local\Temp\ipykernel_35612\972982123.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_체육도장.rename(columns={'SIGNGU_ACCTO_FCLTY_CO':'체육도장 수', 'SIGNGU_NM':'자치구'}, inplace=True)
#       체육도장 수
# 자치구
# 종로구       23
# 중구        31
# 용산구       32
# 성동구       52
# 광진구       82
# 동대문구      70
# 중랑구       84
# 성북구      117
# ...

# %%
result = pd.concat([df_공공간이운동장, df_공공수영장, df_민간수영장, df_체육도장, df_골프장_골프연습장, df_공공체력단련장, df_민간체력단련장, df_당구장, ], axis=1)
result
# Out:
#       공공간이운동장 수  공공수영장 수  민간수영장 수  체육도장 수  골프/골프연습장 수  공공체력단련장 수  민간체력단련장 수  \
# 자치구
# 종로구          28        3        0      23          33          3         59
# 중구            3        2        7      31          93          5        110
# 용산구           8        4        3      32          41          4         76
# 성동구           0        4        2      52          54          4         78
# 광진구           5        3        6      82          56          1        121
# 동대문구          5        3        4      70          45          7         82
# 중랑구           7        2        2      84          34          3         74
# 성북구          40        3        6     117          49          6         88
# 강북구          40        2        0      64          22          2         54
# 도봉구          78        1        2      83          36          3         63
# 노원구          40        2        6     137          86          1         89
# ...

# %%
result['수영장 수'] = result['공공수영장 수'] + result['민간수영장 수']
result['체력단련장 수'] = result['공공체력단련장 수'] + result['민간체력단련장 수']
result
# Out:
#       공공간이운동장 수  공공수영장 수  민간수영장 수  체육도장 수  골프/골프연습장 수  공공체력단련장 수  민간체력단련장 수  \
# 자치구
# 종로구          28        3        0      23          33          3         59
# 중구            3        2        7      31          93          5        110
# 용산구           8        4        3      32          41          4         76
# 성동구           0        4        2      52          54          4         78
# 광진구           5        3        6      82          56          1        121
# 동대문구          5        3        4      70          45          7         82
# 중랑구           7        2        2      84          34          3         74
# 성북구          40        3        6     117          49          6         88
# 강북구          40        2        0      64          22          2         54
# 도봉구          78        1        2      83          36          3         63
# 노원구          40        2        6     137          86          1         89
# ...

# %%
result.drop(['공공수영장 수', '민간수영장 수', '공공체력단련장 수', '민간체력단련장 수'],axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\morat\AI\2023_Data_Campus\2023_Data_Campus\데청캠 프로젝트 eda\data\체육생활이용정보_전처리.ipynb Cell 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/morat/AI/2023_Data_Campus/2023_Data_Campus/%EB%8D%B0%EC%B2%AD%EC%BA%A0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%20eda/data/%EC%B2%B4%EC%9C%A1%EC%83%9D%ED%99%9C%EC%9D%B4%EC%9A%A9%EC%A0%95%EB%B3%B4_%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> result.drop(['공공수영장 수', '민간수영장 수', '공공체력단련장 수', '민간체력단련장 수'],axis=1, inplace=True)
# ...

# %%
result.rename(columns={'공공간이운동장 수':'간이운동장 수'}, inplace=True)
result
# Out:
#       간이운동장 수  체육도장 수  골프/골프연습장 수  당구장 수  수영장 수  체력단련장 수
# 자치구
# 종로구        28      23          33     88      3       62
# 중구          3      31          93    170      9      115
# 용산구         8      32          41     42      7       80
# 성동구         0      52          54     71      6       82
# 광진구         5      82          56    129      9      122
# 동대문구        5      70          45     83      7       89
# 중랑구         7      84          34    106      4       77
# 성북구        40     117          49    133      9       94
# 강북구        40      64          22     94      2       56
# 도봉구        78      83          36    100      3       66
# 노원구        40     137          86    110      8       90
# 은평구        27      98          48    120      5       99
# 서대문구       23      63          27     58      3       49
# 마포구       100      81          76     81      7      150
# 양천구         2     141          91    105     17      132
# ...

# %%
result.to_csv('../data/체육시설수전처리.csv')
