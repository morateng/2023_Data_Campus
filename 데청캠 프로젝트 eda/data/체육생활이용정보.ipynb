# %%
import pandas as pd

# %%
df = pd.read_csv('../data/체육 생활 이용정보_202303.csv')
df.head()
# Out:
#    BASE_YM   CTPRVN_CD CTPRVN_NM   SIGNGU_CD SIGNGU_NM  \
# 0   202008  1100000000     서울특별시  1111000000       종로구
# 1   202008  1100000000     서울특별시  1111000000       종로구
# 2   202008  1100000000     서울특별시  1111000000       종로구
# 3   202008  1100000000     서울특별시  1111000000       종로구
# 4   202008  1100000000     서울특별시  1111000000       종로구
#
#    SIGNGU_ACCTO_POPLTN_CO MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM  \
# 0                  149962          자주이용하는 공공시설 1순위               간이운동장
# 1                  149962          자주이용하는 민간시설 1순위               체력단련장
# 2                  149962          자주이용하는 공공시설 2순위               체력단련장
# 3                  149962          자주이용하는 민간시설 2순위           골프장/골프연습장
# 4                  149962          자주이용하는 공공시설 3순위                 수영장
#
#    SIGNGU_ACCTO_FCLTY_CO  PSNBY_FCLTY_CO  PSNBY_FCL_CO_RANK_CO
# 0                     28         0.00019                   132
# 1                     47         0.00031                     6
# ...

# %%
df_seoul = df[df['CTPRVN_NM'].str.contains('서울특별시')]
df_seoul
# Out:
#        BASE_YM   CTPRVN_CD CTPRVN_NM   SIGNGU_CD SIGNGU_NM  \
# 0       202008  1100000000     서울특별시  1111000000       종로구
# 1       202008  1100000000     서울특별시  1111000000       종로구
# 2       202008  1100000000     서울특별시  1111000000       종로구
# 3       202008  1100000000     서울특별시  1111000000       종로구
# 4       202008  1100000000     서울특별시  1111000000       종로구
# ...        ...         ...       ...         ...       ...
# 69325   202303  1100000000     서울특별시  1174000000       강동구
# 69326   202303  1100000000     서울특별시  1174000000       강동구
# 69327   202303  1100000000     서울특별시  1174000000       강동구
# 69328   202303  1100000000     서울특별시  1174000000       강동구
# 69329   202303  1100000000     서울특별시  1174000000       강동구
#
#        SIGNGU_ACCTO_POPLTN_CO MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM  \
# 0                      149962          자주이용하는 공공시설 1순위               간이운동장
# 1                      149962          자주이용하는 민간시설 1순위               체력단련장
# ...

# %%
df_seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7750 entries, 0 to 69329
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   BASE_YM                   7750 non-null   int64
#  1   CTPRVN_CD                 7750 non-null   int64
#  2   CTPRVN_NM                 7750 non-null   object
#  3   SIGNGU_CD                 7750 non-null   int64
#  4   SIGNGU_NM                 7750 non-null   object
#  5   SIGNGU_ACCTO_POPLTN_CO    7750 non-null   int64
#  6   MAIN_DMAND_FCLTY_FLAG_NM  7750 non-null   object
#  7   MAIN_DMAND_FCLTY_NM       7750 non-null   object
#  8   SIGNGU_ACCTO_FCLTY_CO     7750 non-null   int64
#  9   PSNBY_FCLTY_CO            7750 non-null   float64
#  10  PSNBY_FCL_CO_RANK_CO      7750 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 726.6+ KB

# %%
df_seoul=df_seoul[df_seoul['BASE_YM']==202303]
df_seoul.head(15)
# Out:
#        BASE_YM   CTPRVN_CD CTPRVN_NM   SIGNGU_CD SIGNGU_NM  \
# 69080   202303  1100000000     서울특별시  1111000000       종로구
# 69081   202303  1100000000     서울특별시  1111000000       종로구
# 69082   202303  1100000000     서울특별시  1111000000       종로구
# 69083   202303  1100000000     서울특별시  1111000000       종로구
# 69084   202303  1100000000     서울특별시  1111000000       종로구
# 69085   202303  1100000000     서울특별시  1111000000       종로구
# 69086   202303  1100000000     서울특별시  1111000000       종로구
# 69087   202303  1100000000     서울특별시  1111000000       종로구
# 69088   202303  1100000000     서울특별시  1111000000       종로구
# 69089   202303  1100000000     서울특별시  1111000000       종로구
# 69090   202303  1100000000     서울특별시  1114000000        중구
# 69091   202303  1100000000     서울특별시  1114000000        중구
# 69092   202303  1100000000     서울특별시  1114000000        중구
# 69093   202303  1100000000     서울특별시  1114000000        중구
# 69094   202303  1100000000     서울특별시  1114000000        중구
#
# ...

# %%
df_seoul.drop(['CTPRVN_CD', 'SIGNGU_CD'], axis=1, inplace=True)

# %%
df_seoul.head(10)
# Out:
#        BASE_YM CTPRVN_NM SIGNGU_NM  SIGNGU_ACCTO_POPLTN_CO  \
# 69080   202303     서울특별시       종로구                  141060
# 69081   202303     서울특별시       종로구                  141060
# 69082   202303     서울특별시       종로구                  141060
# 69083   202303     서울특별시       종로구                  141060
# 69084   202303     서울특별시       종로구                  141060
# 69085   202303     서울특별시       종로구                  141060
# 69086   202303     서울특별시       종로구                  141060
# 69087   202303     서울특별시       종로구                  141060
# 69088   202303     서울특별시       종로구                  141060
# 69089   202303     서울특별시       종로구                  141060
#
#       MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM  SIGNGU_ACCTO_FCLTY_CO  \
# 69080          자주이용하는 공공시설 1순위               간이운동장                     28
# 69081          자주이용하는 민간시설 1순위               체력단련장                     59
# 69082          자주이용하는 공공시설 2순위               체력단련장                      3
# ...

# %% [markdown]
# ### 공공시설 1순위만 자치구마다 보기

# %%
df_seoul.loc[69080::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM']]
# Out:
#       SIGNGU_NM MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM
# 69080       종로구          자주이용하는 공공시설 1순위               간이운동장
# 69090        중구          자주이용하는 공공시설 1순위               간이운동장
# 69100       용산구          자주이용하는 공공시설 1순위               간이운동장
# 69110       성동구          자주이용하는 공공시설 1순위               간이운동장
# 69120       광진구          자주이용하는 공공시설 1순위               간이운동장
# 69130      동대문구          자주이용하는 공공시설 1순위               간이운동장
# 69140       중랑구          자주이용하는 공공시설 1순위               간이운동장
# 69150       성북구          자주이용하는 공공시설 1순위               간이운동장
# 69160       강북구          자주이용하는 공공시설 1순위               간이운동장
# 69170       도봉구          자주이용하는 공공시설 1순위               간이운동장
# 69180       노원구          자주이용하는 공공시설 1순위               간이운동장
# 69190       은평구          자주이용하는 공공시설 1순위               간이운동장
# 69200      서대문구          자주이용하는 공공시설 1순위               간이운동장
# 69210       마포구          자주이용하는 공공시설 1순위               간이운동장
# ...

# %% [markdown]
# ### 민간시설 1순위

# %%
df_seoul.loc[69081::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM']]
# Out:
#       SIGNGU_NM MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM
# 69081       종로구          자주이용하는 민간시설 1순위               체력단련장
# 69091        중구          자주이용하는 민간시설 1순위               체력단련장
# 69101       용산구          자주이용하는 민간시설 1순위               체력단련장
# 69111       성동구          자주이용하는 민간시설 1순위               체력단련장
# 69121       광진구          자주이용하는 민간시설 1순위               체력단련장
# 69131      동대문구          자주이용하는 민간시설 1순위               체력단련장
# 69141       중랑구          자주이용하는 민간시설 1순위               체력단련장
# 69151       성북구          자주이용하는 민간시설 1순위               체력단련장
# 69161       강북구          자주이용하는 민간시설 1순위               체력단련장
# 69171       도봉구          자주이용하는 민간시설 1순위               체력단련장
# 69181       노원구          자주이용하는 민간시설 1순위               체력단련장
# 69191       은평구          자주이용하는 민간시설 1순위               체력단련장
# 69201      서대문구          자주이용하는 민간시설 1순위               체력단련장
# 69211       마포구          자주이용하는 민간시설 1순위               체력단련장
# ...

# %%
df_seoul.loc[69082::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM']]
# Out:
#       SIGNGU_NM MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM
# 69082       종로구          자주이용하는 공공시설 2순위               체력단련장
# 69092        중구          자주이용하는 공공시설 2순위               체력단련장
# 69102       용산구          자주이용하는 공공시설 2순위               체력단련장
# 69112       성동구          자주이용하는 공공시설 2순위               체력단련장
# 69122       광진구          자주이용하는 공공시설 2순위               체력단련장
# 69132      동대문구          자주이용하는 공공시설 2순위               체력단련장
# 69142       중랑구          자주이용하는 공공시설 2순위               체력단련장
# 69152       성북구          자주이용하는 공공시설 2순위               체력단련장
# 69162       강북구          자주이용하는 공공시설 2순위               체력단련장
# 69172       도봉구          자주이용하는 공공시설 2순위               체력단련장
# 69182       노원구          자주이용하는 공공시설 2순위               체력단련장
# 69192       은평구          자주이용하는 공공시설 2순위               체력단련장
# 69202      서대문구          자주이용하는 공공시설 2순위               체력단련장
# 69212       마포구          자주이용하는 공공시설 2순위               체력단련장
# ...

# %%
df_seoul.loc[69083::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM']]
# Out:
#       SIGNGU_NM MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM
# 69083       종로구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69093        중구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69103       용산구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69113       성동구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69123       광진구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69133      동대문구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69143       중랑구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69153       성북구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69163       강북구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69173       도봉구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69183       노원구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69193       은평구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69203      서대문구          자주이용하는 민간시설 2순위           골프장/골프연습장
# 69213       마포구          자주이용하는 민간시설 2순위           골프장/골프연습장
# ...

# %%
df_seoul.loc[69084::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM']]
# Out:
#       SIGNGU_NM MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM
# 69084       종로구          자주이용하는 공공시설 3순위                 수영장
# 69094        중구          자주이용하는 공공시설 3순위                 수영장
# 69104       용산구          자주이용하는 공공시설 3순위                 수영장
# 69114       성동구          자주이용하는 공공시설 3순위                 수영장
# 69124       광진구          자주이용하는 공공시설 3순위                 수영장
# 69134      동대문구          자주이용하는 공공시설 3순위                 수영장
# 69144       중랑구          자주이용하는 공공시설 3순위                 수영장
# 69154       성북구          자주이용하는 공공시설 3순위                 수영장
# 69164       강북구          자주이용하는 공공시설 3순위                 수영장
# 69174       도봉구          자주이용하는 공공시설 3순위                 수영장
# 69184       노원구          자주이용하는 공공시설 3순위                 수영장
# 69194       은평구          자주이용하는 공공시설 3순위                 수영장
# 69204      서대문구          자주이용하는 공공시설 3순위                 수영장
# 69214       마포구          자주이용하는 공공시설 3순위                 수영장
# ...

# %%
df_seoul.loc[69085::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM']]
# Out:
#       SIGNGU_NM MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM
# 69085       종로구          자주이용하는 민간시설 3순위                 수영장
# 69095        중구          자주이용하는 민간시설 3순위                 수영장
# 69105       용산구          자주이용하는 민간시설 3순위                 수영장
# 69115       성동구          자주이용하는 민간시설 3순위                 수영장
# 69125       광진구          자주이용하는 민간시설 3순위                 수영장
# 69135      동대문구          자주이용하는 민간시설 3순위                 수영장
# 69145       중랑구          자주이용하는 민간시설 3순위                 수영장
# 69155       성북구          자주이용하는 민간시설 3순위                 수영장
# 69165       강북구          자주이용하는 민간시설 3순위                 수영장
# 69175       도봉구          자주이용하는 민간시설 3순위                 수영장
# 69185       노원구          자주이용하는 민간시설 3순위                 수영장
# 69195       은평구          자주이용하는 민간시설 3순위                 수영장
# 69205      서대문구          자주이용하는 민간시설 3순위                 수영장
# 69215       마포구          자주이용하는 민간시설 3순위                 수영장
# ...

# %% [markdown]
# ### 간이운동장, 체력단련장(헬스장), 골프장/골프연습장, 수영장을 많이 이용

# %%
df_seoul.loc[69086::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM']]
# Out:
#       SIGNGU_NM MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM
# 69086       종로구          자주이용하는 공공시설 4순위                 축구장
# 69096        중구          자주이용하는 공공시설 4순위                 축구장
# 69106       용산구          자주이용하는 공공시설 4순위                 축구장
# 69116       성동구          자주이용하는 공공시설 4순위                 축구장
# 69126       광진구          자주이용하는 공공시설 4순위                 축구장
# 69136      동대문구          자주이용하는 공공시설 4순위                 축구장
# 69146       중랑구          자주이용하는 공공시설 4순위                 축구장
# 69156       성북구          자주이용하는 공공시설 4순위                 축구장
# 69166       강북구          자주이용하는 공공시설 4순위                 축구장
# 69176       도봉구          자주이용하는 공공시설 4순위                 축구장
# 69186       노원구          자주이용하는 공공시설 4순위                 축구장
# 69196       은평구          자주이용하는 공공시설 4순위                 축구장
# 69206      서대문구          자주이용하는 공공시설 4순위                 축구장
# 69216       마포구          자주이용하는 공공시설 4순위                 축구장
# ...

# %%
df_seoul.loc[69087::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM']]
# Out:
#       SIGNGU_NM MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM
# 69087       종로구          자주이용하는 민간시설 4순위                 당구장
# 69097        중구          자주이용하는 민간시설 4순위                 당구장
# 69107       용산구          자주이용하는 민간시설 4순위                 당구장
# 69117       성동구          자주이용하는 민간시설 4순위                 당구장
# 69127       광진구          자주이용하는 민간시설 4순위                 당구장
# 69137      동대문구          자주이용하는 민간시설 4순위                 당구장
# 69147       중랑구          자주이용하는 민간시설 4순위                 당구장
# 69157       성북구          자주이용하는 민간시설 4순위                 당구장
# 69167       강북구          자주이용하는 민간시설 4순위                 당구장
# 69177       도봉구          자주이용하는 민간시설 4순위                 당구장
# 69187       노원구          자주이용하는 민간시설 4순위                 당구장
# 69197       은평구          자주이용하는 민간시설 4순위                 당구장
# 69207      서대문구          자주이용하는 민간시설 4순위                 당구장
# 69217       마포구          자주이용하는 민간시설 4순위                 당구장
# ...

# %%
df_seoul.loc[69088::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM']]
# Out:
#       SIGNGU_NM MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM
# 69088       종로구          자주이용하는 공공시설 5순위                테니스장
# 69098        중구          자주이용하는 공공시설 5순위                테니스장
# 69108       용산구          자주이용하는 공공시설 5순위                테니스장
# 69118       성동구          자주이용하는 공공시설 5순위                테니스장
# 69128       광진구          자주이용하는 공공시설 5순위                테니스장
# 69138      동대문구          자주이용하는 공공시설 5순위                테니스장
# 69148       중랑구          자주이용하는 공공시설 5순위                테니스장
# 69158       성북구          자주이용하는 공공시설 5순위                테니스장
# 69168       강북구          자주이용하는 공공시설 5순위                테니스장
# 69178       도봉구          자주이용하는 공공시설 5순위                테니스장
# 69188       노원구          자주이용하는 공공시설 5순위                테니스장
# 69198       은평구          자주이용하는 공공시설 5순위                테니스장
# 69208      서대문구          자주이용하는 공공시설 5순위                테니스장
# 69218       마포구          자주이용하는 공공시설 5순위                테니스장
# ...

# %%
df_seoul.loc[69089::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM']]
# Out:
#       SIGNGU_NM MAIN_DMAND_FCLTY_FLAG_NM MAIN_DMAND_FCLTY_NM
# 69089       종로구          자주이용하는 민간시설 5순위                체육도장
# 69099        중구          자주이용하는 민간시설 5순위                체육도장
# 69109       용산구          자주이용하는 민간시설 5순위                체육도장
# 69119       성동구          자주이용하는 민간시설 5순위                체육도장
# 69129       광진구          자주이용하는 민간시설 5순위                체육도장
# 69139      동대문구          자주이용하는 민간시설 5순위                체육도장
# 69149       중랑구          자주이용하는 민간시설 5순위                체육도장
# 69159       성북구          자주이용하는 민간시설 5순위                체육도장
# 69169       강북구          자주이용하는 민간시설 5순위                체육도장
# 69179       도봉구          자주이용하는 민간시설 5순위                체육도장
# 69189       노원구          자주이용하는 민간시설 5순위                체육도장
# 69199       은평구          자주이용하는 민간시설 5순위                체육도장
# 69209      서대문구          자주이용하는 민간시설 5순위                체육도장
# 69219       마포구          자주이용하는 민간시설 5순위                체육도장
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize = (20,8))
sns.barplot(x='SIGNGU_NM', y='PSNBY_FCLTY_CO',data=df_seoul.loc[69080::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM','PSNBY_FCLTY_CO']])
plt.xlabel('자치구')
plt.ylabel('간이운동장 인당 시설수')
plt.title('간이운동장 인당 시설수(공공1위)')
# Out:
# Text(0.5, 1.0, '간이운동장 인당 시설수(공공1위)')

# %%
plt.figure(figsize = (20,8))
sns.barplot(x='SIGNGU_NM', y='PSNBY_FCLTY_CO',data=df_seoul.loc[69081::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM','PSNBY_FCLTY_CO']])
plt.xlabel('자치구')
plt.ylabel('헬스장 인당 시설수')
plt.title('자치구 헬스장 인당 시설수(민간 1위)')
# Out:
# Text(0.5, 1.0, '자치구 헬스장 인당 시설수(민간 1위)')

# %%
plt.figure(figsize = (20,8))
sns.barplot(x='SIGNGU_NM', y='PSNBY_FCLTY_CO',data=df_seoul.loc[69082::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM','PSNBY_FCLTY_CO']])
plt.xlabel('자치구')
plt.ylabel('헬스장 인당 시설수')
plt.title('자치구 헬스장 인당 시설수(공공2위)')
# Out:
# Text(0.5, 1.0, '자치구 헬스장 인당 시설수(공공2위)')
# c:\Users\morat\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\morat\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize = (20,8))
sns.barplot(x='SIGNGU_NM', y='PSNBY_FCLTY_CO',data=df_seoul.loc[69083::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM','PSNBY_FCLTY_CO']])
plt.xlabel('자치구')
plt.ylabel('골프장 인당 시설수')
plt.title('자치구 골프장 인당 시설수(민간2위)')
# Out:
# Text(0.5, 1.0, '자치구 골프장 인당 시설수(민간2위)')

# %%
plt.figure(figsize = (20,8))
sns.barplot(x='SIGNGU_NM', y='PSNBY_FCLTY_CO',data=df_seoul.loc[69084::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM','PSNBY_FCLTY_CO']])
plt.xlabel('자치구')
plt.ylabel('공공수영장 인당 시설수')
plt.title('자치구 수영장 인당 시설수(공공3위)')
# Out:
# Text(0.5, 1.0, '자치구 수영장 인당 시설수(공공3위)')
# c:\Users\morat\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\morat\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize = (20,8))
sns.barplot(x='SIGNGU_NM', y='PSNBY_FCLTY_CO',data=df_seoul.loc[69085::10,['SIGNGU_NM', 'MAIN_DMAND_FCLTY_FLAG_NM', 'MAIN_DMAND_FCLTY_NM','PSNBY_FCLTY_CO']])
plt.xlabel('자치구')
plt.ylabel('민간수영장 인당 시설수')
plt.title('자치구 민간수영장 인당 시설수(민간3위)')
# Out:
# Text(0.5, 1.0, '자치구 민간수영장 인당 시설수(민간3위)')
# c:\Users\morat\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\morat\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
