# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/시설수데이터+만족도.csv')
df.drop('자치구', axis=1, inplace=True)
df.drop('만족도(평균/5점만점)', axis=1, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()   
df_scaled = pd.DataFrame(scaler.fit_transform(df))
df_scaled
# Out:
#           0         1         2         3         4         5         6   \
# 0   1.956832  0.024296 -0.846134 -0.524891 -0.436436  0.229347  4.350719
# 1  -0.627167  0.103031 -0.021003  0.933139 -0.436436 -0.589750 -0.475164
# 2  -0.539574  0.912882  1.029163  0.933139 -0.436436 -0.043685 -0.475164
# 3   0.073578  0.946626  0.429068 -0.524891  2.291288 -0.316718 -0.289553
# 4  -0.145405  0.541701  3.504554  2.391169 -0.436436 -0.589750 -0.289553
# 5  -0.276795  0.980370 -0.546086 -0.524891  2.291288 -0.316718 -0.382358
# 6  -0.189201  0.834147  2.379376 -0.524891 -0.436436 -0.043685 -0.475164
# 7  -0.364388 -0.313143  0.129020 -0.524891 -0.436436 -0.589750 -0.567969
# 8  -0.758557  0.429221 -0.621098 -0.524891  2.291288 -0.043685 -0.289553
# 9  -0.670964 -0.065688  0.054009  2.391169 -0.436436 -0.589750 -0.567969
# 10 -0.276795 -0.470614  0.129020  2.391169 -0.436436 -0.589750 -0.475164
# 11 -0.627167 -0.571845 -0.621098 -0.524891 -0.436436 -0.589750 -0.289553
# ...

# %%
from sklearn.decomposition import PCA

# Perform PCA
pca = PCA()
principal_components = pca.fit_transform(df_scaled)

# Calculate explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Calculate weights based on explained variance ratio
weights = explained_variance_ratio / np.sum(explained_variance_ratio)

# Print the weights
print("PCA-based Weights:")
for i, weight in enumerate(weights):
    print(f"Variable {i + 1}: {weight:.50f}")
# Out:
# PCA-based Weights:
# Variable 1: 0.38333582484649381116881272646423894912004470825195
# Variable 2: 0.17736046728642448910839846121234586462378501892090
# Variable 3: 0.07990121354088788874214799307083012536168098449707
# Variable 4: 0.07078254902941069626187697849672986194491386413574
# Variable 5: 0.05278846523641181343045047924533719196915626525879
# Variable 6: 0.04754310494842281520355697921331739053130149841309
# Variable 7: 0.03531137833195438502364993382798274978995323181152
# Variable 8: 0.03019513649229591326084154445652529830113053321838
# Variable 9: 0.02217110656818696221015407843424327438697218894958
# Variable 10: 0.02034477515702476022041444991828029742464423179626
# Variable 11: 0.01930108666017009075299704079498042119666934013367
# Variable 12: 0.01430289947605789535600706585682928562164306640625
# Variable 13: 0.01214700329138151783936461214352675597183406352997
# Variable 14: 0.00841715383013367894615708308947432669810950756073
# ...

# %%
# Out:
# 8.582822907716027e-34

# %%
pca.explained_variance_ratio_
# Out:
# array([0.38333582])

# %%
pca.explained_variance_ratio_
# Out:
# array([3.83335825e-01, 1.77360467e-01, 7.99012135e-02, 7.07825490e-02,
#        5.27884652e-02, 4.75431049e-02, 3.53113783e-02, 3.01951365e-02,
#        2.21711066e-02, 2.03447752e-02, 1.93010867e-02, 1.43028995e-02,
#        1.21470033e-02, 8.41715383e-03, 6.09025139e-03, 5.81432877e-03,
#        4.57233039e-03, 3.84943179e-03, 2.82579742e-03, 1.11868469e-03,
#        7.69768672e-04, 5.96748644e-04, 3.19238583e-04, 1.41254949e-04,
#        8.58282291e-34])

# %%
from sklearn.decomposition import PCA



# Calculate the correlation matrix
#correlation_matrix = df_scaled.corr()

# Perform PCA
pca = PCA()
pca.fit(df_scaled)

# 주성분(PC)과 그에 대응하는 가중치 출력
for i, pc in enumerate(pca.components_):
    print(f"Principal Component {i + 1} weights:")
    for j, weight in enumerate(pc):
        print(f"Variable {j + 1}: {weight}")
# Out:
# Principal Component 1 weights:
# Variable 1: 0.14644987628017178
# Variable 2: 0.08105949761844443
# Variable 3: -0.06216411658075484
# Variable 4: -0.08156231579787088
# Variable 5: 0.007180178130855176
# Variable 6: 0.15530252136714198
# Variable 7: 0.25837321699052485
# Variable 8: 0.2558598939537302
# Variable 9: 0.23098007975604523
# Variable 10: 0.22457797896822687
# Variable 11: -0.010938910545764156
# Variable 12: 0.17593530901474524
# Variable 13: 0.15607930099079462
# Variable 14: 0.26517498327907857
# Variable 15: 0.26151082727841535
# Variable 16: 0.21635815448845105
# Variable 17: 0.1500105097025453
# Variable 18: 0.17575903026480746
# Variable 19: 0.2807029400834462
# Variable 20: 0.21621024085714072
# Variable 21: 0.20043721198901426
# Variable 22: 0.2771915887710814
# Variable 23: 0.18624705662112012
# Variable 24: 0.2546104809262843
# Variable 25: 0.17980425375314515
# Variable 26: 0.018214664010936726
# Variable 27: 0.016094216444008085
# ...

# %%
pca_weight_df = pd.DataFrame(pca.components_)
pca_weight_df
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.146450  0.081059 -0.062164 -0.081562  0.007180  0.155303  0.258373
# 1   0.262265 -0.295970 -0.119997 -0.043688 -0.127576 -0.121613  0.082362
# 2   0.076679  0.177188  0.017689 -0.187044  0.309405  0.204089 -0.167933
# 3  -0.215701  0.042769  0.153263  0.134302 -0.084420  0.051121  0.094122
# 4   0.261001  0.117365  0.584438  0.412099 -0.037258 -0.156696 -0.028453
# 5  -0.033422  0.225444  0.184397  0.264123 -0.518292  0.379971 -0.022233
# 6   0.129856  0.045058 -0.161036 -0.234190 -0.254411  0.340269  0.021241
# 7  -0.075337 -0.291428 -0.049302 -0.147367 -0.258346 -0.132986  0.051919
# 8  -0.018906  0.260770  0.393568 -0.567135  0.078769 -0.192272  0.047907
# 9  -0.316015  0.183000 -0.105945  0.271520  0.313150 -0.184572  0.143551
# 10  0.180400 -0.167092  0.120471  0.085191  0.119209 -0.264051 -0.154249
# 11  0.123664 -0.064097 -0.015476  0.255395  0.038142  0.013760 -0.146120
# ...
