# %%
import pandas as pd

# %%
df = pd.read_csv('../data/서울공공도서관현황.csv.csv', encoding='CP949')
df
# Out:
#      도서관 일련번호         도서관명  구 코드   구명                                    주소  \
# 0        1935    강남구립못골도서관     8  강남구                     서울특별시 강남구 자곡로 116
# 1        1066   강남역삼푸른솔도서관     8  강남구               서울특별시 강남구 테헤란로8길 36. 4층
# 2          48        논현도서관     8  강남구  서울특별시 강남구 학동로43길 17(논현동) 논현2동주민센터 6층
# 3          49        대치도서관     8  강남구  서울특별시 강남구 삼성로 212 은마아파트 복지상가 2층 215호
# 4        1402    도곡정보문화도서관     8  강남구                   서울특별시 강남구 도곡로18길 57
# ..        ...          ...   ...  ...                                   ...
# 198      2144      양원숲속도서관    20  중랑구                서울특별시 중랑구 송림길 172(망우동)
# 199        29  중랑구립면목정보도서관    20  중랑구                서울특별시 중랑구 면목로 397(면목동)
# 200        28    중랑구립정보도서관    20  중랑구              서울특별시 중랑구 신내로15길 197(묵동)
# 201      2638      중랑상봉도서관    20  중랑구             서울특별시 중랑구 동일로114길 10(상봉동)
# 202      1078    중랑숲어린이도서관    20  중랑구            서울특별시 중랑구 망우로73길 46-1(망우동)
#
# ...

# %%
value_counts = df['구명'].value_counts()
value_counts.to_csv('../data/도서관수.csv')
