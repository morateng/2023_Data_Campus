# %%
# 리퀘스트 이용, html 데이터 가져오기


# 뷰티풀수프 이용, html 데이터 파싱


# 판다스 이용, csv로 저장
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
# 리퀘스트 이용, html 데이터 가져오기


keyword = "짜장면"

# url = "https://search.naver.com/search.naver?where=news&sm=tab_jum&query=" + keyword

page = 10

list_final = []

for i in range(1,page+1) : 
    url_new = "https://search.naver.com/search.naver?&where=news&query=" + keyword + "&sm=tab_pge&sort=0&photo=0&field=0&reporter_article=&pd=0&ds=&de=&docid=&nso=so:r,p:all,a:all&mynews=0&cluster_rank=90&start=" + str(page-1)  + "1&refresh_start=0"
    res = requests.get(url_new)
    html_raw = res.text

    # 뷰티풀 수프 이용, html 데이터 파싱

    soup = BeautifulSoup(html_raw, 'html.parser')
    articles = soup.select("ul.type01 > li")
    for article in articles :
        result = {
            'title' : article.select("a._sp_each_title")[0]['title'],
            'link' : article.select("a._sp_each_title")[0]['href'],
            'media' : article.select("span._sp_each_source")[0].text,
            'description' : article.select("dl > dd")[1].text,
        }
        list_final.append(result)

    
# 판다스 이용, csv로 저장
df = pd.DataFrame(list_final)

display(df)
df.to_csv(keyword + "naver_news_100.csv",encoding='utf-8-sig')
# Out:
#                                           description  \
# 0   위해 짜장면 나눔 행사를 진행했다. 이번 행사는 표 대표와 박 대표가 신종코로나로 ...
# 1   이마트(139480)는 자사 가정간편식 브랜드 피코크를 통해 ‘맛이차이나’ 짜장면 ...
# 2   서귀포시는 2일 관내 식당에서 학교밖청소년지원센터 종사가 20여 명이 참여한 가운데...
# 3   중국집 배달원의 “짜장면 시키신 분~”이라는 외침이 유난히 크게 들리던 구장이었다....
# 4   ⓒ 남소연 "짜장면 한 그릇 시키주소." 지난 18일, 대구광역시 수성대학교 정문에...
# 5   수영동 행정복지센터 제공 “마스크 한 장 기부하면, 짜장면 한 그릇 무료로 드립니다...
# 6   바로 짜장면인데요. 하지만 요즘은 너무나 쉽게 접하는 음식이 됐습니다. 100여 년...
# 7   이무송은 짬뽕을, 나는 짜장면을 시켰다”라고 말했다. 이어 “내 짜장면에 고춧가루를...
# 8   '생활의 달인'에 당진 대파자장면과 김치짬뽕 달인, 중고 자동차 감별 달인, 반찬 ...
# 9   하지만 남은 문구 중에도 '하하하하하하하' '짜장면이 좋아? 아니면 짬뽕이 좋아?'...
# 10  위해 짜장면 나눔 행사를 진행했다. 이번 행사는 표 대표와 박 대표가 신종코로나로 ...
# 11  이마트(139480)는 자사 가정간편식 브랜드 피코크를 통해 ‘맛이차이나’ 짜장면 ...
# 12  서귀포시는 2일 관내 식당에서 학교밖청소년지원센터 종사가 20여 명이 참여한 가운데...
# 13  중국집 배달원의 “짜장면 시키신 분~”이라는 외침이 유난히 크게 들리던 구장이었다....
# 14  ⓒ 남소연 "짜장면 한 그릇 시키주소." 지난 18일, 대구광역시 수성대학교 정문에...
# 15  수영동 행정복지센터 제공 “마스크 한 장 기부하면, 짜장면 한 그릇 무료로 드립니다...
# 16  바로 짜장면인데요. 하지만 요즘은 너무나 쉽게 접하는 음식이 됐습니다. 100여 년...
# 17  이무송은 짬뽕을, 나는 짜장면을 시켰다”라고 말했다. 이어 “내 짜장면에 고춧가루를...
# 18  '생활의 달인'에 당진 대파자장면과 김치짬뽕 달인, 중고 자동차 감별 달인, 반찬 ...
# 19  하지만 남은 문구 중에도 '하하하하하하하' '짜장면이 좋아? 아니면 짬뽕이 좋아?'...
# 20  위해 짜장면 나눔 행사를 진행했다. 이번 행사는 표 대표와 박 대표가 신종코로나로 ...
# 21  이마트(139480)는 자사 가정간편식 브랜드 피코크를 통해 ‘맛이차이나’ 짜장면 ...
# 22  서귀포시는 2일 관내 식당에서 학교밖청소년지원센터 종사가 20여 명이 참여한 가운데...
# 23  중국집 배달원의 “짜장면 시키신 분~”이라는 외침이 유난히 크게 들리던 구장이었다....
# 24  ⓒ 남소연 "짜장면 한 그릇 시키주소." 지난 18일, 대구광역시 수성대학교 정문에...
# 25  수영동 행정복지센터 제공 “마스크 한 장 기부하면, 짜장면 한 그릇 무료로 드립니다...
# 26  바로 짜장면인데요. 하지만 요즘은 너무나 쉽게 접하는 음식이 됐습니다. 100여 년...
# 27  이무송은 짬뽕을, 나는 짜장면을 시켰다”라고 말했다. 이어 “내 짜장면에 고춧가루를...
# 28  '생활의 달인'에 당진 대파자장면과 김치짬뽕 달인, 중고 자동차 감별 달인, 반찬 ...
# 29  하지만 남은 문구 중에도 '하하하하하하하' '짜장면이 좋아? 아니면 짬뽕이 좋아?'...
# ..                                                ...
# 70  위해 짜장면 나눔 행사를 진행했다. 이번 행사는 표 대표와 박 대표가 신종코로나로 ...
# 71  이마트(139480)는 자사 가정간편식 브랜드 피코크를 통해 ‘맛이차이나’ 짜장면 ...
# 72  서귀포시는 2일 관내 식당에서 학교밖청소년지원센터 종사가 20여 명이 참여한 가운데...
# 73  중국집 배달원의 “짜장면 시키신 분~”이라는 외침이 유난히 크게 들리던 구장이었다....
# 74  ⓒ 남소연 "짜장면 한 그릇 시키주소." 지난 18일, 대구광역시 수성대학교 정문에...
# 75  수영동 행정복지센터 제공 “마스크 한 장 기부하면, 짜장면 한 그릇 무료로 드립니다...
# 76  바로 짜장면인데요. 하지만 요즘은 너무나 쉽게 접하는 음식이 됐습니다. 100여 년...
# 77  이무송은 짬뽕을, 나는 짜장면을 시켰다”라고 말했다. 이어 “내 짜장면에 고춧가루를...
# 78  '생활의 달인'에 당진 대파자장면과 김치짬뽕 달인, 중고 자동차 감별 달인, 반찬 ...
# 79  하지만 남은 문구 중에도 '하하하하하하하' '짜장면이 좋아? 아니면 짬뽕이 좋아?'...
# 80  위해 짜장면 나눔 행사를 진행했다. 이번 행사는 표 대표와 박 대표가 신종코로나로 ...
# 81  이마트(139480)는 자사 가정간편식 브랜드 피코크를 통해 ‘맛이차이나’ 짜장면 ...
# 82  서귀포시는 2일 관내 식당에서 학교밖청소년지원센터 종사가 20여 명이 참여한 가운데...
# 83  중국집 배달원의 “짜장면 시키신 분~”이라는 외침이 유난히 크게 들리던 구장이었다....
# 84  ⓒ 남소연 "짜장면 한 그릇 시키주소." 지난 18일, 대구광역시 수성대학교 정문에...
# 85  수영동 행정복지센터 제공 “마스크 한 장 기부하면, 짜장면 한 그릇 무료로 드립니다...
# 86  바로 짜장면인데요. 하지만 요즘은 너무나 쉽게 접하는 음식이 됐습니다. 100여 년...
# 87  이무송은 짬뽕을, 나는 짜장면을 시켰다”라고 말했다. 이어 “내 짜장면에 고춧가루를...
# 88  '생활의 달인'에 당진 대파자장면과 김치짬뽕 달인, 중고 자동차 감별 달인, 반찬 ...
# 89  하지만 남은 문구 중에도 '하하하하하하하' '짜장면이 좋아? 아니면 짬뽕이 좋아?'...
# 90  위해 짜장면 나눔 행사를 진행했다. 이번 행사는 표 대표와 박 대표가 신종코로나로 ...
# 91  이마트(139480)는 자사 가정간편식 브랜드 피코크를 통해 ‘맛이차이나’ 짜장면 ...
# 92  서귀포시는 2일 관내 식당에서 학교밖청소년지원센터 종사가 20여 명이 참여한 가운데...
# 93  중국집 배달원의 “짜장면 시키신 분~”이라는 외침이 유난히 크게 들리던 구장이었다....
# 94  ⓒ 남소연 "짜장면 한 그릇 시키주소." 지난 18일, 대구광역시 수성대학교 정문에...
# 95  수영동 행정복지센터 제공 “마스크 한 장 기부하면, 짜장면 한 그릇 무료로 드립니다...
# 96  바로 짜장면인데요. 하지만 요즘은 너무나 쉽게 접하는 음식이 됐습니다. 100여 년...
# 97  이무송은 짬뽕을, 나는 짜장면을 시켰다”라고 말했다. 이어 “내 짜장면에 고춧가루를...
# 98  '생활의 달인'에 당진 대파자장면과 김치짬뽕 달인, 중고 자동차 감별 달인, 반찬 ...
# 99  하지만 남은 문구 중에도 '하하하하하하하' '짜장면이 좋아? 아니면 짬뽕이 좋아?'...
#
#                                                  link         media  \
# 0   http://www.ksilbo.co.kr/news/articleView.html?...          경상일보
# 1   http://biz.chosun.com/site/data/html_dir/2019/...          조선비즈
# 2   http://www.jejunews.com/news/articleView.html?...          제주신보
# 3   http://news.khan.co.kr/kh_news/khan_art_view.h...          경향신문
# 4   http://www.ohmynews.com/NWS_Web/View/at_pg.asp...   오마이뉴스언론사 선정
# 5   http://www.busan.com/view/busan/view.php?code=...    부산일보언론사 선정
# 6   http://news.kbs.co.kr/news/view.do?ncd=4311315...           KBS
# 7             http://mksports.co.kr/view/2020/556790/         MK스포츠
# 8   http://ilyo.co.kr/?ac=article_view&entry_id=36...          일요신문
# 9       http://www.fnnews.com/news/201910222058301100  파이낸셜뉴스언론사 선정
# 10  http://www.ksilbo.co.kr/news/articleView.html?...          경상일보
# 11  http://biz.chosun.com/site/data/html_dir/2019/...          조선비즈
# 12  http://www.jejunews.com/news/articleView.html?...          제주신보
# 13  http://news.khan.co.kr/kh_news/khan_art_view.h...          경향신문
# 14  http://www.ohmynews.com/NWS_Web/View/at_pg.asp...   오마이뉴스언론사 선정
# 15  http://www.busan.com/view/busan/view.php?code=...    부산일보언론사 선정
# 16  http://news.kbs.co.kr/news/view.do?ncd=4311315...           KBS
# 17            http://mksports.co.kr/view/2020/556790/         MK스포츠
# 18  http://ilyo.co.kr/?ac=article_view&entry_id=36...          일요신문
# 19      http://www.fnnews.com/news/201910222058301100  파이낸셜뉴스언론사 선정
# 20  http://www.ksilbo.co.kr/news/articleView.html?...          경상일보
# 21  http://biz.chosun.com/site/data/html_dir/2019/...          조선비즈
# 22  http://www.jejunews.com/news/articleView.html?...          제주신보
# 23  http://news.khan.co.kr/kh_news/khan_art_view.h...          경향신문
# 24  http://www.ohmynews.com/NWS_Web/View/at_pg.asp...   오마이뉴스언론사 선정
# 25  http://www.busan.com/view/busan/view.php?code=...    부산일보언론사 선정
# 26  http://news.kbs.co.kr/news/view.do?ncd=4311315...           KBS
# 27            http://mksports.co.kr/view/2020/556790/         MK스포츠
# 28  http://ilyo.co.kr/?ac=article_view&entry_id=36...          일요신문
# 29      http://www.fnnews.com/news/201910222058301100  파이낸셜뉴스언론사 선정
# ..                                                ...           ...
# 70  http://www.ksilbo.co.kr/news/articleView.html?...          경상일보
# 71  http://biz.chosun.com/site/data/html_dir/2019/...          조선비즈
# 72  http://www.jejunews.com/news/articleView.html?...          제주신보
# 73  http://news.khan.co.kr/kh_news/khan_art_view.h...          경향신문
# 74  http://www.ohmynews.com/NWS_Web/View/at_pg.asp...   오마이뉴스언론사 선정
# 75  http://www.busan.com/view/busan/view.php?code=...    부산일보언론사 선정
# 76  http://news.kbs.co.kr/news/view.do?ncd=4311315...           KBS
# 77            http://mksports.co.kr/view/2020/556790/         MK스포츠
# 78  http://ilyo.co.kr/?ac=article_view&entry_id=36...          일요신문
# 79      http://www.fnnews.com/news/201910222058301100  파이낸셜뉴스언론사 선정
# 80  http://www.ksilbo.co.kr/news/articleView.html?...          경상일보
# 81  http://biz.chosun.com/site/data/html_dir/2019/...          조선비즈
# 82  http://www.jejunews.com/news/articleView.html?...          제주신보
# 83  http://news.khan.co.kr/kh_news/khan_art_view.h...          경향신문
# 84  http://www.ohmynews.com/NWS_Web/View/at_pg.asp...   오마이뉴스언론사 선정
# 85  http://www.busan.com/view/busan/view.php?code=...    부산일보언론사 선정
# 86  http://news.kbs.co.kr/news/view.do?ncd=4311315...           KBS
# 87            http://mksports.co.kr/view/2020/556790/         MK스포츠
# 88  http://ilyo.co.kr/?ac=article_view&entry_id=36...          일요신문
# 89      http://www.fnnews.com/news/201910222058301100  파이낸셜뉴스언론사 선정
# 90  http://www.ksilbo.co.kr/news/articleView.html?...          경상일보
# 91  http://biz.chosun.com/site/data/html_dir/2019/...          조선비즈
# 92  http://www.jejunews.com/news/articleView.html?...          제주신보
# 93  http://news.khan.co.kr/kh_news/khan_art_view.h...          경향신문
# 94  http://www.ohmynews.com/NWS_Web/View/at_pg.asp...   오마이뉴스언론사 선정
# 95  http://www.busan.com/view/busan/view.php?code=...    부산일보언론사 선정
# 96  http://news.kbs.co.kr/news/view.do?ncd=4311315...           KBS
# 97            http://mksports.co.kr/view/2020/556790/         MK스포츠
# 98  http://ilyo.co.kr/?ac=article_view&entry_id=36...          일요신문
# 99      http://www.fnnews.com/news/201910222058301100  파이낸셜뉴스언론사 선정
#
#                                            title
# 0                 중앙동 지역 건물주·임차인, 독거노인 짜장면 나눔 행사
# 1                         이마트, 짜장면·짬뽕 밀키트 신제품 출시
# 2                 서귀포시, 학교 밖 청소년 '사랑의 짜장면 데이' 운영
# 3                    썰렁한 야구장엔 함성 대신 “짜장면 시키신 분~”
# 4         김부겸의 이유 있는 짜장면 '5분컷'... "TK홀대론 먹히니 문제"
# 5        ‘마스크 1장 기부 = 짜장면 한 그릇’…기부받아 소외계층에 전달 계획
# 6          [똑! 기자 꿀! 정보] 돌 짜장면에서 망치 짜장면까지…별별 짜장면
# 7   ‘미우새’ 노사연 “이무송과 신혼 초 짜장면 때문에 이혼할 뻔” [MK★TV픽]
# 8         '생활의 달인' 당진 대파짜장면&김치짬뽕 달인, 반찬 김치 달인 출연
# 9               '짜장면이 좋아?' 마포대교 자살 예방문구 7년 만에 제거
# 10                중앙동 지역 건물주·임차인, 독거노인 짜장면 나눔 행사
# 11                        이마트, 짜장면·짬뽕 밀키트 신제품 출시
# 12                서귀포시, 학교 밖 청소년 '사랑의 짜장면 데이' 운영
# 13                   썰렁한 야구장엔 함성 대신 “짜장면 시키신 분~”
# 14        김부겸의 이유 있는 짜장면 '5분컷'... "TK홀대론 먹히니 문제"
# 15       ‘마스크 1장 기부 = 짜장면 한 그릇’…기부받아 소외계층에 전달 계획
# 16         [똑! 기자 꿀! 정보] 돌 짜장면에서 망치 짜장면까지…별별 짜장면
# 17  ‘미우새’ 노사연 “이무송과 신혼 초 짜장면 때문에 이혼할 뻔” [MK★TV픽]
# 18        '생활의 달인' 당진 대파짜장면&김치짬뽕 달인, 반찬 김치 달인 출연
# 19              '짜장면이 좋아?' 마포대교 자살 예방문구 7년 만에 제거
# 20                중앙동 지역 건물주·임차인, 독거노인 짜장면 나눔 행사
# 21                        이마트, 짜장면·짬뽕 밀키트 신제품 출시
# 22                서귀포시, 학교 밖 청소년 '사랑의 짜장면 데이' 운영
# 23                   썰렁한 야구장엔 함성 대신 “짜장면 시키신 분~”
# 24        김부겸의 이유 있는 짜장면 '5분컷'... "TK홀대론 먹히니 문제"
# 25       ‘마스크 1장 기부 = 짜장면 한 그릇’…기부받아 소외계층에 전달 계획
# 26         [똑! 기자 꿀! 정보] 돌 짜장면에서 망치 짜장면까지…별별 짜장면
# 27  ‘미우새’ 노사연 “이무송과 신혼 초 짜장면 때문에 이혼할 뻔” [MK★TV픽]
# 28        '생활의 달인' 당진 대파짜장면&김치짬뽕 달인, 반찬 김치 달인 출연
# 29              '짜장면이 좋아?' 마포대교 자살 예방문구 7년 만에 제거
# ..                                           ...
# 70                중앙동 지역 건물주·임차인, 독거노인 짜장면 나눔 행사
# 71                        이마트, 짜장면·짬뽕 밀키트 신제품 출시
# 72                서귀포시, 학교 밖 청소년 '사랑의 짜장면 데이' 운영
# 73                   썰렁한 야구장엔 함성 대신 “짜장면 시키신 분~”
# 74        김부겸의 이유 있는 짜장면 '5분컷'... "TK홀대론 먹히니 문제"
# 75       ‘마스크 1장 기부 = 짜장면 한 그릇’…기부받아 소외계층에 전달 계획
# 76         [똑! 기자 꿀! 정보] 돌 짜장면에서 망치 짜장면까지…별별 짜장면
# 77  ‘미우새’ 노사연 “이무송과 신혼 초 짜장면 때문에 이혼할 뻔” [MK★TV픽]
# 78        '생활의 달인' 당진 대파짜장면&김치짬뽕 달인, 반찬 김치 달인 출연
# 79              '짜장면이 좋아?' 마포대교 자살 예방문구 7년 만에 제거
# 80                중앙동 지역 건물주·임차인, 독거노인 짜장면 나눔 행사
# 81                        이마트, 짜장면·짬뽕 밀키트 신제품 출시
# 82                서귀포시, 학교 밖 청소년 '사랑의 짜장면 데이' 운영
# 83                   썰렁한 야구장엔 함성 대신 “짜장면 시키신 분~”
# 84        김부겸의 이유 있는 짜장면 '5분컷'... "TK홀대론 먹히니 문제"
# 85       ‘마스크 1장 기부 = 짜장면 한 그릇’…기부받아 소외계층에 전달 계획
# 86         [똑! 기자 꿀! 정보] 돌 짜장면에서 망치 짜장면까지…별별 짜장면
# 87  ‘미우새’ 노사연 “이무송과 신혼 초 짜장면 때문에 이혼할 뻔” [MK★TV픽]
# 88        '생활의 달인' 당진 대파짜장면&김치짬뽕 달인, 반찬 김치 달인 출연
# 89              '짜장면이 좋아?' 마포대교 자살 예방문구 7년 만에 제거
# 90                중앙동 지역 건물주·임차인, 독거노인 짜장면 나눔 행사
# 91                        이마트, 짜장면·짬뽕 밀키트 신제품 출시
# 92                서귀포시, 학교 밖 청소년 '사랑의 짜장면 데이' 운영
# 93                   썰렁한 야구장엔 함성 대신 “짜장면 시키신 분~”
# 94        김부겸의 이유 있는 짜장면 '5분컷'... "TK홀대론 먹히니 문제"
# 95       ‘마스크 1장 기부 = 짜장면 한 그릇’…기부받아 소외계층에 전달 계획
# 96         [똑! 기자 꿀! 정보] 돌 짜장면에서 망치 짜장면까지…별별 짜장면
# 97  ‘미우새’ 노사연 “이무송과 신혼 초 짜장면 때문에 이혼할 뻔” [MK★TV픽]
# 98        '생활의 달인' 당진 대파짜장면&김치짬뽕 달인, 반찬 김치 달인 출연
# 99              '짜장면이 좋아?' 마포대교 자살 예방문구 7년 만에 제거
#
# [100 rows x 4 columns]
